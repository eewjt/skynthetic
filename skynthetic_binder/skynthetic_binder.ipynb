# %% [markdown]
# <style>td {font-size: 1000px}</style>

# %% [markdown]
# <style>td {font-size: 1000px}</style>
#
# # <font color='indianred'>Sk</font><font color='cornflowerblue'>ynthetic</font>
#
# ### *sketch to synthetic*

# %%
from skynthetic import skynthetic as sk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-35c5a41fb99b> in <module>
# ----> 1 from skynthetic import skynthetic as sk
#
# ModuleNotFoundError: No module named 'skynthetic'

# %%
sk.go('images/annot.png', 30)
# Out:
# Building sketchthetic...
# Done

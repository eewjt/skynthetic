# %% [markdown]
# ***
#
# # <ins><font size="6"><font color='indianred'>*Sk*</font><font color='cornflowerblue'>ynthetic</font></font></ins> //  <ins><font size="6"><font color='indianred'>*Sketch*</font><font color='cornflowerblue'>thetic</font></font></ins>//  <ins><font size="6"><font color='indianred'>*Seis*</font><font color='cornflowerblue'>draw</font></font></ins>
#
#
# ### <font size="4"><font color='indianred'>sketch</font> to <font color='cornflowerblue'>seismic</font></font>
# ***

# %%
from skynthetic import skyn

# %%
skyn.go('images/annot.png', 30)
# Out:
# Building skynthetic...
# Done
